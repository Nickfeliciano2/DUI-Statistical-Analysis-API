# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json 
import csv
import os

#output file
output_data_file = "Census_output/Census_data_total_2007.csv"

# Files to load
pop = os.path.join('Population_Resources', 'state-population.csv')
age =  os.path.join('Population_Resources', 'raw_data_age_2007.csv')
race = os.path.join('Population_Resources', 'raw_data_race_2007.csv')
gender = os.path.join('Population_Resources','raw_data_gender_2007.csv')
employment = os.path.join('Population_Resources', 'raw_data_employment_2007.csv')

pop_df = pd.read_csv(pop,skiprows=3, names=['State_Census_2007',"ages_Census_2007", "year_Census_2007",'Population_Census_2007'])
age_df = pd.read_csv(age, skiprows=3,names=['State_Census_2007',"Children 0-18_Census_2007", "Adults 19-25_Census_2007",
                                            "Adults 26-34_Census_2007", "Adults 35-54_Census_2007",'Adults 55-64_Census_2007','65+_Census_2007','Total','8'])
race_df = pd.read_csv(race, skiprows=3,names=['State_Census_2007',"White_Census_2007", "Hispanic_Census_2007","Black_Census_2007",'American Indian/Alaska Native_Census_2007',
                                      'Asian+_Census_2007','Native Hawaiian/Other Pacific Islander_Census_2007',
                                      'Two Or More Races_Census_2007', 'Total', 'Delete'])
gender_df = pd.read_csv(gender, skiprows=3, names=['State_Census_2007','Male_Census_2007',"Female_Census_2007", "Total",'Delete'])
employment_df = pd.read_csv(employment, skiprows=3, names=['State_Census_2007','Delete1',"Delete2", "Unemployed_Census_2007",'Employed','Delete3'])

# %%
pop_total = pop_df[pop_df ["ages_Census_2007"] == 'total'] 
pop_year_2007 = pop_total[pop_total['year_Census_2007'] == 2007]
pop_year_2007 = pop_year_2007.drop(columns=['ages_Census_2007', 'year_Census_2007'])
pop_year_2007.columns = ['State_Census_2007', 'Population_Census_2007']
pop_year_2007 = pop_year_2007.replace(['USA'],'United States')
pop_year_2007 = pop_year_2007.replace(['AK'], 'Alaska')
pop_year_2007 = pop_year_2007.replace(['AL'], 'Alabama')
pop_year_2007 = pop_year_2007.replace(['AR'], 'Arkansas')
pop_year_2007 = pop_year_2007.replace(['AS'], 'American Samoa')
pop_year_2007 = pop_year_2007.replace(['AZ'], 'Arizona')
pop_year_2007 = pop_year_2007.replace(['CA'], 'California')
pop_year_2007 = pop_year_2007.replace(['CO'], 'Colorado')
pop_year_2007 = pop_year_2007.replace(['CT'], 'Connecticut')
pop_year_2007 = pop_year_2007.replace(['DC'], 'District of Columbia')
pop_year_2007 = pop_year_2007.replace(['DE'], 'Delaware')
pop_year_2007 = pop_year_2007.replace(['FL'], 'Florida')
pop_year_2007 = pop_year_2007.replace(['GA'], 'Georgia')
pop_year_2007 = pop_year_2007.replace(['GU'], 'Guam')
pop_year_2007 = pop_year_2007.replace(['HI'], 'Hawaii')
pop_year_2007 = pop_year_2007.replace(['IA'], 'Iowa')
pop_year_2007 = pop_year_2007.replace(['ID'], 'Idaho')
pop_year_2007 = pop_year_2007.replace(['IL'], 'Illinois')
pop_year_2007 = pop_year_2007.replace(['IN'], 'Indiana')
pop_year_2007 = pop_year_2007.replace(['KS'], 'Kansas')
pop_year_2007 = pop_year_2007.replace(['KY'], 'Kentucky')
pop_year_2007 = pop_year_2007.replace(['LA'], 'Louisiana')
pop_year_2007 = pop_year_2007.replace(['MA'], 'Massachusetts')
pop_year_2007 = pop_year_2007.replace(['MD'], 'Maryland')
pop_year_2007 = pop_year_2007.replace(['ME'], 'Maine')
pop_year_2007 = pop_year_2007.replace(['MI'], 'Michigan')
pop_year_2007 = pop_year_2007.replace(['MN'], 'Minnesota')
pop_year_2007 = pop_year_2007.replace(['MO'], 'Missouri')
pop_year_2007 = pop_year_2007.replace(['MP'], 'Northern Mariana Islands')
pop_year_2007 = pop_year_2007.replace(['MS'], 'Mississippi')
pop_year_2007 = pop_year_2007.replace(['MT'], 'Montana')
pop_year_2007 = pop_year_2007.replace(['NA'], 'National')
pop_year_2007 = pop_year_2007.replace(['NC'], 'North Carolina')
pop_year_2007 = pop_year_2007.replace(['ND'], 'North Dakota')
pop_year_2007 = pop_year_2007.replace(['NE'], 'Nebraska')
pop_year_2007 = pop_year_2007.replace(['NH'], 'New Hampshire')
pop_year_2007 = pop_year_2007.replace(['NJ'], 'New Jersey')
pop_year_2007 = pop_year_2007.replace(['NM'], 'New Mexico')
pop_year_2007 = pop_year_2007.replace(['NV'], 'Nevada')
pop_year_2007 = pop_year_2007.replace(['NY'], 'New York')
pop_year_2007 = pop_year_2007.replace(['OH'], 'Ohio')
pop_year_2007 = pop_year_2007.replace(['OK'], 'Oklahoma')
pop_year_2007 = pop_year_2007.replace(['OR'], 'Oregon')
pop_year_2007 = pop_year_2007.replace(['PA'], 'Pennsylvania')
pop_year_2007 = pop_year_2007.replace(['PR'], 'Puerto Rico')
pop_year_2007 = pop_year_2007.replace(['RI'], 'Rhode Island')
pop_year_2007 = pop_year_2007.replace(['SC'], 'South Carolina')
pop_year_2007 = pop_year_2007.replace(['SD'], 'South Dakota')
pop_year_2007 = pop_year_2007.replace(['TN'], 'Tennessee')
pop_year_2007 = pop_year_2007.replace(['TX'], 'Texas')
pop_year_2007 = pop_year_2007.replace(['UT'], 'Utah')
op_year_2007 = pop_year_2007.replace(['VA'], 'Virginia')
pop_year_2007 = pop_year_2007.replace(['VI'], 'Virgin Islands')
pop_year_2007 = pop_year_2007.replace(['VT'], 'Vermont')
pop_year_2007 = pop_year_2007.replace(['WA'], 'Washington')
pop_year_2007 = pop_year_2007.replace(['WI'], 'Wisconsin',)
pop_year_2007 = pop_year_2007.replace(['WV'], 'West Virginia')
pop_year_2007 = pop_year_2007.replace(['WY'], 'Wyoming')
pop_year_2007
# Out:
#          State_Census_2007  Population_Census_2007
# 32           United States             301231207.0
# 55                 Alabama               4672840.0
# 127                 Alaska                680300.0
# 151                Arizona               6167681.0
# 225               Arkansas               2848650.0
# 247             California              36250311.0
# 321               Colorado               4803868.0
# 343            Connecticut               3527270.0
# 417               Delaware                871749.0
# 439   District of Columbia                574404.0
# 511                Florida              18367842.0
# 535                Georgia               9349988.0
# 609                 Hawaii               1315675.0
# 631                  Idaho               1505105.0
# 705               Illinois              12695866.0
# 727                Indiana               6379599.0
# 801                   Iowa               2999212.0
# ...

# %%
race_df = race_df.drop(columns=['Delete'])
race_df = race_df.drop(columns=['Total'])
race_df.head()
# Out:
#   State_Census_2007  White_Census_2007  Hispanic_Census_2007  \
# 0     United States        193573200.0            35033200.0
# 1           Alabama          3108700.0             1169700.0
# 2            Alaska           433100.0               18700.0
# 3           Arizona          3704300.0              214500.0
# 4          Arkansas          2096900.0              422400.0
#
#    Black_Census_2007  American Indian/Alaska Native_Census_2007  \
# 0         45753600.0                                  1919700.0
# 1           124800.0                                    22200.0
# 2            34600.0                                    86900.0
# 3          1922100.0                                   261200.0
# 4           152500.0                                    15900.0
#
#    Asian+_Census_2007  Native Hawaiian/Other Pacific Islander_Census_2007  \
# 0          12947100.0                                           384400.0
# ...

# %%
gender_df = gender_df.drop(columns=['Delete','Total'])
gender_df = gender_df.dropna()
gender_df.head()
# Out:
#   State_Census_2007  Male_Census_2007  Female_Census_2007
# 0     United States              0.49                0.51
# 1           Alabama              0.48                0.52
# 2            Alaska              0.51                0.49
# 3           Arizona              0.50                0.50
# 4          Arkansas              0.49                0.51

# %%
employment_df = employment_df.drop(columns=['Delete1','Delete2', 'Delete3'])
employment_df = employment_df.dropna()
employment_df.head()
# Out:
#   State_Census_2007  Unemployed_Census_2007     Employed
# 0     United States              25556400.0  258069500.0
# 1           Alabama                551500.0    3914500.0
# 2            Alaska                 59000.0     606600.0
# 3           Arizona                569200.0    5512100.0
# 4          Arkansas                321300.0    2379500.0

# %%
age_df = age_df.drop(columns=['8'])
age_df = age_df.drop(columns=['Total'])
age_df = age_df.dropna()
age_df.head()
# Out:
#   State_Census_2007  Children 0-18_Census_2007  Adults 19-25_Census_2007  \
# 0     United States                 76770400.0                27241500.0
# 1           Alabama                  1168700.0                  429900.0
# 2            Alaska                   184700.0                   74100.0
# 3           Arizona                  1776500.0                  572900.0
# 4          Arkansas                   727200.0                  250300.0
#
#    Adults 26-34_Census_2007  Adults 35-54_Census_2007  \
# 0                34823900.0                85799700.0
# 1                  509400.0                 1274800.0
# 2                   79700.0                  189300.0
# 3                  801300.0                 1691800.0
# 4                  314800.0                  763200.0
#
#    Adults 55-64_Census_2007  65+_Census_2007
# 0                33433900.0       37200300.0
# 1                  531800.0         612400.0
# 2                   78700.0          48100.0
# ...

# %%
Census_data_1 = pd.merge(race_df,gender_df, on=["State_Census_2007"])
Census_data_1.head()
# Out:
#   State_Census_2007  White_Census_2007  Hispanic_Census_2007  \
# 0     United States        193573200.0            35033200.0
# 1           Alabama          3108700.0             1169700.0
# 2            Alaska           433100.0               18700.0
# 3           Arizona          3704300.0              214500.0
# 4          Arkansas          2096900.0              422400.0
#
#    Black_Census_2007  American Indian/Alaska Native_Census_2007  \
# 0         45753600.0                                  1919700.0
# 1           124800.0                                    22200.0
# 2            34600.0                                    86900.0
# 3          1922100.0                                   261200.0
# 4           152500.0                                    15900.0
#
#    Asian+_Census_2007  Native Hawaiian/Other Pacific Islander_Census_2007  \
# 0          12947100.0                                           384400.0
# ...

# %%
Census_data_2 = pd.merge(Census_data_1,employment_df, on=["State_Census_2007"])
Census_data_2.head()
# Out:
#   State_Census_2007  White_Census_2007  Hispanic_Census_2007  \
# 0     United States        193573200.0            35033200.0
# 1           Alabama          3108700.0             1169700.0
# 2            Alaska           433100.0               18700.0
# 3           Arizona          3704300.0              214500.0
# 4          Arkansas          2096900.0              422400.0
#
#    Black_Census_2007  American Indian/Alaska Native_Census_2007  \
# 0         45753600.0                                  1919700.0
# 1           124800.0                                    22200.0
# 2            34600.0                                    86900.0
# 3          1922100.0                                   261200.0
# 4           152500.0                                    15900.0
#
#    Asian+_Census_2007  Native Hawaiian/Other Pacific Islander_Census_2007  \
# 0          12947100.0                                           384400.0
# ...

# %%
Census_data_3 = pd.merge(Census_data_2,age_df, on=["State_Census_2007"])
Census_data_3.head()
# Out:
#   State_Census_2007  White_Census_2007  Hispanic_Census_2007  \
# 0     United States        193573200.0            35033200.0
# 1           Alabama          3108700.0             1169700.0
# 2            Alaska           433100.0               18700.0
# 3           Arizona          3704300.0              214500.0
# 4          Arkansas          2096900.0              422400.0
#
#    Black_Census_2007  American Indian/Alaska Native_Census_2007  \
# 0         45753600.0                                  1919700.0
# 1           124800.0                                    22200.0
# 2            34600.0                                    86900.0
# 3          1922100.0                                   261200.0
# 4           152500.0                                    15900.0
#
#    Asian+_Census_2007  Native Hawaiian/Other Pacific Islander_Census_2007  \
# 0          12947100.0                                           384400.0
# ...

# %%
Census_data_total = pd.merge(Census_data_3,pop_year_2007, on=["State_Census_2007"])
Census_data_total
# Out:
#        State_Census_2007  White_Census_2007  Hispanic_Census_2007  \
# 0          United States        193573200.0            35033200.0
# 1                Alabama          3108700.0             1169700.0
# 2                 Alaska           433100.0               18700.0
# 3                Arizona          3704300.0              214500.0
# 4               Arkansas          2096900.0              422400.0
# 5             California         15080500.0             2071300.0
# 6               Colorado          3422900.0              160700.0
# 7            Connecticut          2498400.0              298400.0
# 8               Delaware           571900.0              168500.0
# 9   District of Columbia           176700.0              301800.0
# 10               Florida         10772300.0             2598100.0
# 11               Georgia          5466500.0             2726500.0
# 12                Hawaii           290100.0               23800.0
# ...

# %%
Census_data_total.to_csv(output_data_file)
