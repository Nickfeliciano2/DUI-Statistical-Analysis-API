# %% [markdown]
# ## Team # 4
# ### Team Member: Jagrati Joshi
#     Task: Source data from 2007 and 2013 NRS csv files and prepare for merge and analysis

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from uszipcode import SearchEngine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-160705c1ce41> in <module>
#       4 import numpy as np
#       5 import requests
# ----> 6 from uszipcode import SearchEngine
#
# ModuleNotFoundError: No module named 'uszipcode'

# %%
# Reading raw csv files
data07_path = "Resource/nrs_2007_final.csv"
data13_path = "Resource/nrs_2013_combined.csv"

# Setting output data file names
output07_data_file = "output/nrs_2007_CleanedData.csv"
output13_data_file = "output/nrs_2013_CleanedData.csv"
# Storing data in raw format in a Dataframe
data07_raw_df = pd.read_csv(data07_path)
print(f"2007 dataframe size is {data07_raw_df.shape}")
data13_raw_df = pd.read_csv(data13_path)
print(f"2013 dataframe size is {data13_raw_df.shape}")
# Out:
# 2007 dataframe size is (11120, 313)
# 2013 dataframe size is (11322, 995)

# %%
# Getting selected columns for the 2007 data
col_list = ["STATE", "NRS_ZIPCODE", "DATE", "session", "NRS_RACE" ,"NRS_DSEX", "NRS_AGE", "NRS_SCHOOL"
            ,"NRS_EMPLOY", "NRS_VTYPE", "NRS_FROM", "NRS_HEADED", "NRS_BETMI", "NRS_TODRK", "resulbac2"]
data07_df = pd.read_csv(data07_path, low_memory=False, usecols=col_list)

# Checking list of columns imported from CSV to ensure matchh with sort listed columns
col_list_check = data07_df.columns.values.tolist()
col_list_check
# Out:
# ['session',
#  'STATE',
#  'DATE',
#  'NRS_FROM',
#  'NRS_HEADED',
#  'NRS_BETMI',
#  'NRS_TODRK',
#  'NRS_AGE',
#  'NRS_ZIPCODE',
#  'NRS_SCHOOL',
#  'NRS_EMPLOY',
#  'NRS_RACE',
#  'NRS_VTYPE',
#  'NRS_DSEX',
#  'resulbac2']

# %%
# Column index 38 has an issue in import hence checking name of the column at index 38
col38_name = data07_raw_df.columns[38]
col38_name
# Out:
# 'NRS_ZIPCODE'

# %%
# Checking datatypes of the 2007 dataframe
data07_df.dtypes
# Out:
# session          int64
# STATE           object
# DATE            object
# NRS_FROM        object
# NRS_HEADED      object
# NRS_BETMI       object
# NRS_TODRK       object
# NRS_AGE         object
# NRS_ZIPCODE     object
# NRS_SCHOOL      object
# NRS_EMPLOY      object
# NRS_RACE        object
# NRS_VTYPE       object
# NRS_DSEX       float64
# resulbac2       object
# dtype: object

# %%
# Displaying 2007 data
data07_df
# Out:
#        session STATE        DATE                      NRS_FROM  \
# 0            3    TN   11/3/2007                           NaN
# 1            1    IL         NaN                           NaN
# 2            1    IN         NaN                           NaN
# 3            1    MI  10/12/2007                           NaN
# 4            5    IA         NaN                           NaN
# ...        ...   ...         ...                           ...
# 11115        2    IN         NaN  Sport or rec facility / park
# 11116        3    PA         NaN     Restaurant / eating place
# 11117        5    FL         NaN                         Other
# 11118        1    PA         NaN     Restaurant / eating place
# 11119        3    IN         NaN                          Work
#
#             NRS_HEADED NRS_BETMI NRS_TODRK NRS_AGE NRS_ZIPCODE  \
# 0                  NaN       NaN       NaN  #NULL!         NaN
# 1                  NaN       NaN       NaN  #NULL!         NaN
# 2                  NaN       NaN       NaN  #NULL!         NaN
# 3                  NaN       NaN       NaN  #NULL!         NaN
# 4                  NaN       NaN       NaN  #NULL!         NaN
# ...                ...       ...       ...     ...         ...
# 11115  Home (own home)     0 - 5        No      48       46373
# 11116  Home (own home)    6 - 10       Yes      39       19038
# 11117  Home (own home)   11 - 20        No      19       33065
# 11118  Home (own home)   16 - 20       NaN  #NULL!       19312
# 11119  Home (own home)   16 - 20        No      47       46307
#
#              NRS_SCHOOL              NRS_EMPLOY NRS_RACE NRS_VTYPE  NRS_DSEX  \
# 0                   NaN                     NaN      NaN       NaN       NaN
# 1                   NaN                     NaN      NaN       NaN       NaN
# 2                   NaN                     NaN      NaN       NaN       NaN
# 3                   NaN                     NaN      NaN       NaN       NaN
# 4                   NaN                     NaN      NaN       NaN       NaN
# ...                 ...                     ...      ...       ...       ...
# 11115      Some college  Employed/self-employed    White       Car       1.0
# 11116  College graduate  Employed/self-employed    White       Car       2.0
# 11117      Some college                 Student    White       Car       2.0
# 11118  College graduate                 Retired    White       Car       2.0
# 11119      Some college  Employed/self-employed    White       Car       2.0
#
#       resulbac2
# 0             0
# 1        #NULL!
# 2             0
# 3             0
# 4        #NULL!
# ...         ...
# 11115         0
# 11116    #NULL!
# 11117    #NULL!
# 11118    #NULL!
# 11119         0
#
# [11120 rows x 15 columns]

# %%
# Checking count of NA or NaN values in the dataframe
data07_df.isna().sum()
# Out:
# session           0
# STATE             0
# DATE           7646
# NRS_FROM       2147
# NRS_HEADED     2148
# NRS_BETMI      2147
# NRS_TODRK      5074
# NRS_AGE           0
# NRS_ZIPCODE    2202
# NRS_SCHOOL     2174
# NRS_EMPLOY     2177
# NRS_RACE       2179
# NRS_VTYPE        73
# NRS_DSEX         73
# resulbac2         0
# dtype: int64

# %%
# Removing all NA or NaN values from the dataframe
data07_df = data07_df
data07_df
# Out:
#        session STATE        DATE                      NRS_FROM  \
# 0            3    TN   11/3/2007                           NaN
# 1            1    IL         NaN                           NaN
# 2            1    IN         NaN                           NaN
# 3            1    MI  10/12/2007                           NaN
# 4            5    IA         NaN                           NaN
# ...        ...   ...         ...                           ...
# 11115        2    IN         NaN  Sport or rec facility / park
# 11116        3    PA         NaN     Restaurant / eating place
# 11117        5    FL         NaN                         Other
# 11118        1    PA         NaN     Restaurant / eating place
# 11119        3    IN         NaN                          Work
#
#             NRS_HEADED NRS_BETMI NRS_TODRK NRS_AGE NRS_ZIPCODE  \
# 0                  NaN       NaN       NaN  #NULL!         NaN
# 1                  NaN       NaN       NaN  #NULL!         NaN
# 2                  NaN       NaN       NaN  #NULL!         NaN
# 3                  NaN       NaN       NaN  #NULL!         NaN
# 4                  NaN       NaN       NaN  #NULL!         NaN
# ...                ...       ...       ...     ...         ...
# 11115  Home (own home)     0 - 5        No      48       46373
# 11116  Home (own home)    6 - 10       Yes      39       19038
# 11117  Home (own home)   11 - 20        No      19       33065
# 11118  Home (own home)   16 - 20       NaN  #NULL!       19312
# 11119  Home (own home)   16 - 20        No      47       46307
#
#              NRS_SCHOOL              NRS_EMPLOY NRS_RACE NRS_VTYPE  NRS_DSEX  \
# 0                   NaN                     NaN      NaN       NaN       NaN
# 1                   NaN                     NaN      NaN       NaN       NaN
# 2                   NaN                     NaN      NaN       NaN       NaN
# 3                   NaN                     NaN      NaN       NaN       NaN
# 4                   NaN                     NaN      NaN       NaN       NaN
# ...                 ...                     ...      ...       ...       ...
# 11115      Some college  Employed/self-employed    White       Car       1.0
# 11116  College graduate  Employed/self-employed    White       Car       2.0
# 11117      Some college                 Student    White       Car       2.0
# 11118  College graduate                 Retired    White       Car       2.0
# 11119      Some college  Employed/self-employed    White       Car       2.0
#
#       resulbac2
# 0             0
# 1        #NULL!
# 2             0
# 3             0
# 4        #NULL!
# ...         ...
# 11115         0
# 11116    #NULL!
# 11117    #NULL!
# 11118    #NULL!
# 11119         0
#
# [11120 rows x 15 columns]

# %%
# Checking count of NA or NaN values in the dataframe after cleanup
data07_df.isna().sum()
# Out:
# session           0
# STATE             0
# DATE           7646
# NRS_FROM       2147
# NRS_HEADED     2148
# NRS_BETMI      2147
# NRS_TODRK      5074
# NRS_AGE           0
# NRS_ZIPCODE    2202
# NRS_SCHOOL     2174
# NRS_EMPLOY     2177
# NRS_RACE       2179
# NRS_VTYPE        73
# NRS_DSEX         73
# resulbac2         0
# dtype: int64

# %%
# Checking datatypes
data07_df.dtypes
# Out:
# session          int64
# STATE           object
# DATE            object
# NRS_FROM        object
# NRS_HEADED      object
# NRS_BETMI       object
# NRS_TODRK       object
# NRS_AGE         object
# NRS_ZIPCODE     object
# NRS_SCHOOL      object
# NRS_EMPLOY      object
# NRS_RACE        object
# NRS_VTYPE       object
# NRS_DSEX       float64
# resulbac2       object
# dtype: object

# %%
# Changing Zipcode to int64 and RACE to string
data07_df = data07_df.astype({"NRS_ZIPCODE": "int64", "NRS_RACE": "string"})
data07_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-1b1aad5b4268> in <module>
#       1 # Changing Zipcode to int64 and RACE to string
# ----> 2 data07_df = data07_df.astype({"NRS_ZIPCODE": "int64", "NRS_RACE": "string"})
#       3 data07_df.dtypes
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5681                 if col_name in dtype:
#    5682                     results.append(
# -> 5683                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5684                     )
#    5685                 else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
search = SearchEngine(simple_zipcode=True)
for index, row in data07_df.iterrows():
    try:
        zipcode = row["NRS_ZIPCODE"]
        getCityData = search.by_zipcode(zipcode)
        data07_df.loc[index, "CityName"] = getCityData.major_city
    except ValueError:
        print(f"Skipping {index} due to invalid zipcode data")

data07_df.head()
# Out:
#       session STATE       DATE         NRS_FROM                 NRS_HEADED  \
# 1968        4    IL  7/22/2007             Work            Home (own home)
# 1990        3    CA  7/28/2022            Other            Home (own home)
# 1992        1    CA  7/27/2007  Home (own home)  Restaurant / eating place
# 1993        3    WI   8/4/2007             Work        Someone else's home
# 1994        2    IL  7/21/2007             Work        Someone else's home
#
#      NRS_BETMI NRS_TODRK NRS_AGE  NRS_ZIPCODE            NRS_SCHOOL  \
# 1968     0 - 5        No      20        60154          Some college
# 1990    6 - 10       Yes      23        90732  High school graduate
# 1992     0 - 5        No      31        90503          Some college
# 1993    6 - 10        No      46        53018          Some college
# 1994     0 - 5        No      21        60613      College graduate
#
#                   NRS_EMPLOY  NRS_RACE NRS_VTYPE  NRS_DSEX resulbac2  \
# 1968  Employed/self-employed  Hispanic       Car       1.0         0
# 1990  Employed/self-employed     White       Car       2.0     0.043
# 1992  Employed/self-employed     White   Minivan       2.0         0
# 1993  Employed/self-employed     White       Car       2.0         0
# 1994  Employed/self-employed     Asian       Car       2.0         0
#
#          CityName
# 1968  Westchester
# 1990    San Pedro
# 1992     Torrance
# 1993    Delafield
# 1994      Chicago

# %%
# Renaming NRS_EMPLOY to AreYouEmployed to match data with 2013
data07_df = data07_df.rename(columns={"NRS_EMPLOY": "AreYouEmployed"})
data07_df.head()
# Out:
#       session STATE       DATE         NRS_FROM                 NRS_HEADED  \
# 1968        4    IL  7/22/2007             Work            Home (own home)
# 1990        3    CA  7/28/2022            Other            Home (own home)
# 1992        1    CA  7/27/2007  Home (own home)  Restaurant / eating place
# 1993        3    WI   8/4/2007             Work        Someone else's home
# 1994        2    IL  7/21/2007             Work        Someone else's home
#
#      NRS_BETMI NRS_TODRK NRS_AGE  NRS_ZIPCODE            NRS_SCHOOL  \
# 1968     0 - 5        No      20        60154          Some college
# 1990    6 - 10       Yes      23        90732  High school graduate
# 1992     0 - 5        No      31        90503          Some college
# 1993    6 - 10        No      46        53018          Some college
# 1994     0 - 5        No      21        60613      College graduate
#
#               AreYouEmployed  NRS_RACE NRS_VTYPE  NRS_DSEX resulbac2  \
# 1968  Employed/self-employed  Hispanic       Car       1.0         0
# 1990  Employed/self-employed     White       Car       2.0     0.043
# 1992  Employed/self-employed     White   Minivan       2.0         0
# 1993  Employed/self-employed     White       Car       2.0         0
# 1994  Employed/self-employed     Asian       Car       2.0         0
#
#          CityName
# 1968  Westchester
# 1990    San Pedro
# 1992     Torrance
# 1993    Delafield
# 1994      Chicago

# %%
# Creating a copy of AreYouEmployed column to match with 2013 AreYouStudent column
data07_df["AreYouStudent"] = data07_df["AreYouEmployed"]
data07_df.head()
# Out:
#       session STATE       DATE         NRS_FROM                 NRS_HEADED  \
# 1968        4    IL  7/22/2007             Work            Home (own home)
# 1990        3    CA  7/28/2022            Other            Home (own home)
# 1992        1    CA  7/27/2007  Home (own home)  Restaurant / eating place
# 1993        3    WI   8/4/2007             Work        Someone else's home
# 1994        2    IL  7/21/2007             Work        Someone else's home
#
#      NRS_BETMI NRS_TODRK NRS_AGE  NRS_ZIPCODE            NRS_SCHOOL  \
# 1968     0 - 5        No      20        60154          Some college
# 1990    6 - 10       Yes      23        90732  High school graduate
# 1992     0 - 5        No      31        90503          Some college
# 1993    6 - 10        No      46        53018          Some college
# 1994     0 - 5        No      21        60613      College graduate
#
#               AreYouEmployed  NRS_RACE NRS_VTYPE  NRS_DSEX resulbac2  \
# 1968  Employed/self-employed  Hispanic       Car       1.0         0
# 1990  Employed/self-employed     White       Car       2.0     0.043
# 1992  Employed/self-employed     White   Minivan       2.0         0
# 1993  Employed/self-employed     White       Car       2.0         0
# 1994  Employed/self-employed     Asian       Car       2.0         0
#
#          CityName           AreYouStudent
# 1968  Westchester  Employed/self-employed
# 1990    San Pedro  Employed/self-employed
# 1992     Torrance  Employed/self-employed
# 1993    Delafield  Employed/self-employed
# 1994      Chicago  Employed/self-employed

# %%
# Checking unique values in AreYouEmployed column
data07_df["AreYouEmployed"].unique()
# Out:
# array(['Employed/self-employed', 'Student', 'On Disability', 'Retired',
#        'Unemployed', 'Homemaker', 'Other'], dtype=object)

# %%
# Converting AreYouEmployed to binary
data07_df["AreYouEmployed"] = data07_df["AreYouEmployed"].apply(lambda x: 1 if x == "Employed/self-employed" else 0)
data07_df
# Out:
#        session STATE       DATE             NRS_FROM  \
# 1968         4    IL  7/22/2007                 Work
# 1990         3    CA  7/28/2022                Other
# 1992         1    CA  7/27/2007      Home (own home)
# 1993         3    WI   8/4/2007                 Work
# 1994         2    IL  7/21/2007                 Work
# ...        ...   ...        ...                  ...
# 11091        4    IL  7/22/2022                Other
# 11095        5    NE   8/5/2007  Someone else's home
# 11097        2    AL  7/21/2007      Home (own home)
# 11101        2    CA  7/28/2007  Someone else's home
# 11102        1    VA  8/10/2007      Home (own home)
#
#                       NRS_HEADED     NRS_BETMI NRS_TODRK NRS_AGE  NRS_ZIPCODE  \
# 1968             Home (own home)         0 - 5        No      20        60154
# 1990             Home (own home)        6 - 10       Yes      23        90732
# 1992   Restaurant / eating place         0 - 5        No      31        90503
# 1993         Someone else's home        6 - 10        No      46        53018
# 1994         Someone else's home         0 - 5        No      21        60613
# ...                          ...           ...       ...     ...          ...
# 11091        Someone else's home        6 - 10       Yes      46        60077
# 11095        Someone else's home         0 - 5       Yes      25        68154
# 11097  Restaurant / eating place  More than 20        No      21        35150
# 11101            Home (own home)  More than 20        No      28        90810
# 11102       Store or gas station         0 - 5        No      41        23227
#
#                  NRS_SCHOOL  AreYouEmployed                   NRS_RACE  \
# 1968           Some college               1                   Hispanic
# 1990   High school graduate               1                      White
# 1992           Some college               1                      White
# 1993           Some college               1                      White
# 1994       College graduate               1                      Asian
# ...                     ...             ...                        ...
# 11091  High school graduate               1                      White
# 11095      College graduate               1                      White
# 11097  High school graduate               1  Black or African American
# 11101          Some college               1  Black or African American
# 11102  High school graduate               1  Black or African American
#
#       NRS_VTYPE  NRS_DSEX resulbac2     CityName           AreYouStudent
# 1968        Car       1.0         0  Westchester  Employed/self-employed
# 1990        Car       2.0     0.043    San Pedro  Employed/self-employed
# 1992    Minivan       2.0         0     Torrance  Employed/self-employed
# 1993        Car       2.0         0    Delafield  Employed/self-employed
# 1994        Car       2.0         0      Chicago  Employed/self-employed
# ...         ...       ...       ...          ...                     ...
# 11091       SUV       2.0         0       Skokie  Employed/self-employed
# 11095       SUV       2.0         0        Omaha  Employed/self-employed
# 11097       SUV       1.0         0    Sylacauga  Employed/self-employed
# 11101       Car       2.0     0.033   Long Beach  Employed/self-employed
# 11102       SUV       2.0         0     Richmond  Employed/self-employed
#
# [1914 rows x 17 columns]

# %%
# Converting AreYouStudent to binary
data07_df["AreYouStudent"] = data07_df["AreYouStudent"].apply(lambda x: 1 if x == "Student" else 0)
data07_df
# Out:
#        session STATE       DATE             NRS_FROM  \
# 1968         4    IL  7/22/2007                 Work
# 1990         3    CA  7/28/2022                Other
# 1992         1    CA  7/27/2007      Home (own home)
# 1993         3    WI   8/4/2007                 Work
# 1994         2    IL  7/21/2007                 Work
# ...        ...   ...        ...                  ...
# 11091        4    IL  7/22/2022                Other
# 11095        5    NE   8/5/2007  Someone else's home
# 11097        2    AL  7/21/2007      Home (own home)
# 11101        2    CA  7/28/2007  Someone else's home
# 11102        1    VA  8/10/2007      Home (own home)
#
#                       NRS_HEADED     NRS_BETMI NRS_TODRK NRS_AGE  NRS_ZIPCODE  \
# 1968             Home (own home)         0 - 5        No      20        60154
# 1990             Home (own home)        6 - 10       Yes      23        90732
# 1992   Restaurant / eating place         0 - 5        No      31        90503
# 1993         Someone else's home        6 - 10        No      46        53018
# 1994         Someone else's home         0 - 5        No      21        60613
# ...                          ...           ...       ...     ...          ...
# 11091        Someone else's home        6 - 10       Yes      46        60077
# 11095        Someone else's home         0 - 5       Yes      25        68154
# 11097  Restaurant / eating place  More than 20        No      21        35150
# 11101            Home (own home)  More than 20        No      28        90810
# 11102       Store or gas station         0 - 5        No      41        23227
#
#                  NRS_SCHOOL  AreYouEmployed                   NRS_RACE  \
# 1968           Some college               1                   Hispanic
# 1990   High school graduate               1                      White
# 1992           Some college               1                      White
# 1993           Some college               1                      White
# 1994       College graduate               1                      Asian
# ...                     ...             ...                        ...
# 11091  High school graduate               1                      White
# 11095      College graduate               1                      White
# 11097  High school graduate               1  Black or African American
# 11101          Some college               1  Black or African American
# 11102  High school graduate               1  Black or African American
#
#       NRS_VTYPE  NRS_DSEX resulbac2     CityName  AreYouStudent
# 1968        Car       1.0         0  Westchester              0
# 1990        Car       2.0     0.043    San Pedro              0
# 1992    Minivan       2.0         0     Torrance              0
# 1993        Car       2.0         0    Delafield              0
# 1994        Car       2.0         0      Chicago              0
# ...         ...       ...       ...          ...            ...
# 11091       SUV       2.0         0       Skokie              0
# 11095       SUV       2.0         0        Omaha              0
# 11097       SUV       1.0         0    Sylacauga              0
# 11101       Car       2.0     0.033   Long Beach              0
# 11102       SUV       2.0         0     Richmond              0
#
# [1914 rows x 17 columns]

# %%
# Checking Unique values for AreYouEmployed and AreYouStudent
print(data07_df["AreYouEmployed"].unique())
print(data07_df["AreYouStudent"].unique())
# Out:
# [1 0]
# [0 1]

# %%
# Checking Unique values for gender
data07_df["NRS_DSEX"].unique()
# Out:
# array([1., 2.])

# %%
# Converting gender from numeric to string
data07_df["NRS_DSEX"] = data07_df["NRS_DSEX"].apply(lambda x: "Male" if x == 1.0 else "Female")
data07_df
# Out:
#        session STATE       DATE             NRS_FROM  \
# 1968         4    IL  7/22/2007                 Work
# 1990         3    CA  7/28/2022                Other
# 1992         1    CA  7/27/2007      Home (own home)
# 1993         3    WI   8/4/2007                 Work
# 1994         2    IL  7/21/2007                 Work
# ...        ...   ...        ...                  ...
# 11091        4    IL  7/22/2022                Other
# 11095        5    NE   8/5/2007  Someone else's home
# 11097        2    AL  7/21/2007      Home (own home)
# 11101        2    CA  7/28/2007  Someone else's home
# 11102        1    VA  8/10/2007      Home (own home)
#
#                       NRS_HEADED     NRS_BETMI NRS_TODRK NRS_AGE  NRS_ZIPCODE  \
# 1968             Home (own home)         0 - 5        No      20        60154
# 1990             Home (own home)        6 - 10       Yes      23        90732
# 1992   Restaurant / eating place         0 - 5        No      31        90503
# 1993         Someone else's home        6 - 10        No      46        53018
# 1994         Someone else's home         0 - 5        No      21        60613
# ...                          ...           ...       ...     ...          ...
# 11091        Someone else's home        6 - 10       Yes      46        60077
# 11095        Someone else's home         0 - 5       Yes      25        68154
# 11097  Restaurant / eating place  More than 20        No      21        35150
# 11101            Home (own home)  More than 20        No      28        90810
# 11102       Store or gas station         0 - 5        No      41        23227
#
#                  NRS_SCHOOL  AreYouEmployed                   NRS_RACE  \
# 1968           Some college               1                   Hispanic
# 1990   High school graduate               1                      White
# 1992           Some college               1                      White
# 1993           Some college               1                      White
# 1994       College graduate               1                      Asian
# ...                     ...             ...                        ...
# 11091  High school graduate               1                      White
# 11095      College graduate               1                      White
# 11097  High school graduate               1  Black or African American
# 11101          Some college               1  Black or African American
# 11102  High school graduate               1  Black or African American
#
#       NRS_VTYPE NRS_DSEX resulbac2     CityName  AreYouStudent
# 1968        Car     Male         0  Westchester              0
# 1990        Car   Female     0.043    San Pedro              0
# 1992    Minivan   Female         0     Torrance              0
# 1993        Car   Female         0    Delafield              0
# 1994        Car   Female         0      Chicago              0
# ...         ...      ...       ...          ...            ...
# 11091       SUV   Female         0       Skokie              0
# 11095       SUV   Female         0        Omaha              0
# 11097       SUV     Male         0    Sylacauga              0
# 11101       Car   Female     0.033   Long Beach              0
# 11102       SUV   Female         0     Richmond              0
#
# [1914 rows x 17 columns]

# %%
# Exporting Final cleaned data to csv
# Naming the index of the dataframe for export to csv
data07_df.index.names = ["nrs_id"]

# Exporting the data to CSV file
data07_df.to_csv(output07_data_file)

# %%
# Getting selected columns for the 2013 data
col_list = ["State", "MyZipCodeIs", "Time_Stamp", "data_session_original", "race_n", "Gender", "DriverAgeYears"
            ,"EducationLevel", "AreYouStudent", "AreYouEmployed", "VehicleType", "FromWhere", "ToWhere"
            ,"MilesTraveling", "AlcoholToday", "bac_from_blood"]
data13_df = pd.read_csv(data13_path, low_memory=False, usecols=col_list)

# Checking list of columns imported from CSV to ensure matchh with sort listed columns
col_list_check = data13_df.columns.values.tolist()
col_list_check
# Out:
# ['data_session_original',
#  'State',
#  'Time_Stamp',
#  'race_n',
#  'Gender',
#  'VehicleType',
#  'FromWhere',
#  'ToWhere',
#  'MilesTraveling',
#  'AlcoholToday',
#  'DriverAgeYears',
#  'MyZipCodeIs',
#  'EducationLevel',
#  'AreYouStudent',
#  'AreYouEmployed',
#  'bac_from_blood']

# %%
# Checking datatypes of the 2013 dataframe
data13_df.dtypes
# Out:
# data_session_original      int64
# State                     object
# Time_Stamp                object
# race_n                    object
# Gender                    object
# VehicleType               object
# FromWhere                 object
# ToWhere                   object
# MilesTraveling            object
# AlcoholToday              object
# DriverAgeYears           float64
# MyZipCodeIs              float64
# EducationLevel            object
# AreYouStudent             object
# AreYouEmployed            object
# bac_from_blood            object
# dtype: object

# %%
# Displaying 2013 data
data13_df
# Out:
#        data_session_original State           Time_Stamp  race_n  Gender  \
# 0                          3    CA  12/07/2013 01:36:27       8    Male
# 1                          3    CA  12/07/2013 01:56:35       1    Male
# 2                          3    CA  12/07/2013 02:17:15       8    Male
# 3                          3    CA  12/07/2013 02:34:15       8    Male
# 4                          3    CA  12/07/2013 02:41:16  #NULL!    Male
# ...                      ...   ...                  ...     ...     ...
# 11317                      4    UT  02/08/2014 23:46:43       1  Female
# 11318                      5    UT  02/09/2014 01:29:47       1  Female
# 11319                      5    UT  02/09/2014 01:43:25       1  Female
# 11320                      5    UT  02/09/2014 02:03:32       1  Female
# 11321                      5    UT  02/09/2014 02:24:44       1    Male
#
#           VehicleType             FromWhere   ToWhere MilesTraveling  \
# 0                 Car                 Other     Other            0-5
# 1                 Car                 Other  Own home   More than 20
# 2                 Car                 Other  Own home            0-5
# 3                 Car   Someone else's home  Own home            0-5
# 4      SUV/ Crossover                   NaN       NaN            NaN
# ...               ...                   ...       ...            ...
# 11317             Car                  Work  Own home          11-20
# 11318  SUV/ Crossover   Someone else's home  Own home          11-20
# 11319             Car   Someone else's home  Own home          11-20
# 11320             Car  Store or gas station     Other           6-10
# 11321             Car     Bar, tavern, club  Own home          11-20
#
#       AlcoholToday  DriverAgeYears  MyZipCodeIs            EducationLevel  \
# 0               No            43.0      93003.0      High school graduate
# 1               No            21.0      93033.0  Some college - no degree
# 2              Yes            23.0      93035.0  Some college - no degree
# 3               No            19.0      93030.0  Some college - no degree
# 4              NaN             NaN          NaN                       NaN
# ...            ...             ...          ...                       ...
# 11317          NaN            56.0      84010.0        Associate's degree
# 11318          NaN            18.0      84054.0      High school graduate
# 11319          NaN            22.0      84037.0  Some college - no degree
# 11320           No            20.0      84606.0  Some college - no degree
# 11321          NaN            22.0      84010.0  Some college - no degree
#
#                            AreYouStudent                    AreYouEmployed  \
# 0                                     No                Employed Full-time
# 1                                     No                Employed Full-time
# 2      Other/ Technical or Trade Program  Other __________________________
# 3            College/ Grad or Law School                Employed Part-time
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 11317                                 No                Employed Full-time
# 11318        College/ Grad or Law School                Employed Part-time
# 11319        College/ Grad or Law School                Employed Part-time
# 11320        College/ Grad or Law School                Employed Part-time
# 11321        College/ Grad or Law School                        Unemployed
#
#       bac_from_blood
# 0             #NULL!
# 1             #NULL!
# 2             #NULL!
# 3                  0
# 4             #NULL!
# ...              ...
# 11317              0
# 11318              0
# 11319              0
# 11320              0
# 11321         #NULL!
#
# [11322 rows x 16 columns]

# %%
# Checking count of NA or NaN values in the dataframe
data13_df.isna().sum()
# Out:
# data_session_original       0
# State                       0
# Time_Stamp                  0
# race_n                      0
# Gender                    275
# VehicleType               253
# FromWhere                2521
# ToWhere                  2522
# MilesTraveling           2526
# AlcoholToday             5189
# DriverAgeYears           2562
# MyZipCodeIs              2573
# EducationLevel           2541
# AreYouStudent            2542
# AreYouEmployed           2544
# bac_from_blood              0
# dtype: int64

# %%
# Removing all NA or NaN values from the dataframe
data13_df = data13_df.dropna()
data13_df
# Out:
#        data_session_original State           Time_Stamp race_n  Gender  \
# 0                          3    CA  12/07/2013 01:36:27      8    Male
# 1                          3    CA  12/07/2013 01:56:35      1    Male
# 2                          3    CA  12/07/2013 02:17:15      8    Male
# 3                          3    CA  12/07/2013 02:34:15      8    Male
# 5                          3    CA  12/07/2013 13:28:52      1    Male
# ...                      ...   ...                  ...    ...     ...
# 11301                      2    UT  02/07/2014 23:25:54      1  Female
# 11302                      2    UT  02/07/2014 23:43:53      1    Male
# 11306                      3    UT  02/08/2014 02:37:35      1    Male
# 11314                      4    UT  02/08/2014 23:01:07      5  Female
# 11320                      5    UT  02/09/2014 02:03:32      1  Female
#
#       VehicleType                FromWhere              ToWhere  \
# 0             Car                    Other                Other
# 1             Car                    Other             Own home
# 2             Car                    Other             Own home
# 3             Car      Someone else's home             Own home
# 5             Car                    Other                Other
# ...           ...                      ...                  ...
# 11301         Car                     Work             Own home
# 11302      Pickup                 Own home  Someone else's home
# 11306         Car                 Own home        School/church
# 11314         Car  Restaurant/eating place             Own home
# 11320         Car     Store or gas station                Other
#
#       MilesTraveling AlcoholToday  DriverAgeYears  MyZipCodeIs  \
# 0                0-5           No            43.0      93003.0
# 1       More than 20           No            21.0      93033.0
# 2                0-5          Yes            23.0      93035.0
# 3                0-5           No            19.0      93030.0
# 5       More than 20           No            23.0      93033.0
# ...              ...          ...             ...          ...
# 11301          11-20           No            21.0      84041.0
# 11302            0-5           No            19.0      84010.0
# 11306   More than 20           No            23.0      84321.0
# 11314            0-5           No            40.0      84010.0
# 11320           6-10           No            20.0      84606.0
#
#                  EducationLevel                      AreYouStudent  \
# 0          High school graduate                                 No
# 1      Some college - no degree                                 No
# 2      Some college - no degree  Other/ Technical or Trade Program
# 3      Some college - no degree        College/ Grad or Law School
# 5      Some college - no degree                                 No
# ...                         ...                                ...
# 11301      High school graduate                                 No
# 11302      High school graduate                        High School
# 11306        Associate's degree        College/ Grad or Law School
# 11314      High school graduate                                 No
# 11320  Some college - no degree        College/ Grad or Law School
#
#                          AreYouEmployed bac_from_blood
# 0                    Employed Full-time         #NULL!
# 1                    Employed Full-time         #NULL!
# 2      Other __________________________         #NULL!
# 3                    Employed Part-time              0
# 5                    Employed Full-time              0
# ...                                 ...            ...
# 11301                Employed Part-time         #NULL!
# 11302                Employed Full-time         #NULL!
# 11306                Employed Full-time         #NULL!
# 11314                Employed Full-time              0
# 11320                Employed Part-time              0
#
# [6068 rows x 16 columns]

# %%
# Checking count of NA or NaN values in the dataframe after cleanup
data13_df.isna().sum()
# Out:
# data_session_original    0
# State                    0
# Time_Stamp               0
# race_n                   0
# Gender                   0
# VehicleType              0
# FromWhere                0
# ToWhere                  0
# MilesTraveling           0
# AlcoholToday             0
# DriverAgeYears           0
# MyZipCodeIs              0
# EducationLevel           0
# AreYouStudent            0
# AreYouEmployed           0
# bac_from_blood           0
# dtype: int64

# %%
# Checking data after cleanup
data13_df
# Out:
#        data_session_original State           Time_Stamp race_n  Gender  \
# 0                          3    CA  12/07/2013 01:36:27      8    Male
# 1                          3    CA  12/07/2013 01:56:35      1    Male
# 2                          3    CA  12/07/2013 02:17:15      8    Male
# 3                          3    CA  12/07/2013 02:34:15      8    Male
# 5                          3    CA  12/07/2013 13:28:52      1    Male
# ...                      ...   ...                  ...    ...     ...
# 11301                      2    UT  02/07/2014 23:25:54      1  Female
# 11302                      2    UT  02/07/2014 23:43:53      1    Male
# 11306                      3    UT  02/08/2014 02:37:35      1    Male
# 11314                      4    UT  02/08/2014 23:01:07      5  Female
# 11320                      5    UT  02/09/2014 02:03:32      1  Female
#
#       VehicleType                FromWhere              ToWhere  \
# 0             Car                    Other                Other
# 1             Car                    Other             Own home
# 2             Car                    Other             Own home
# 3             Car      Someone else's home             Own home
# 5             Car                    Other                Other
# ...           ...                      ...                  ...
# 11301         Car                     Work             Own home
# 11302      Pickup                 Own home  Someone else's home
# 11306         Car                 Own home        School/church
# 11314         Car  Restaurant/eating place             Own home
# 11320         Car     Store or gas station                Other
#
#       MilesTraveling AlcoholToday  DriverAgeYears  MyZipCodeIs  \
# 0                0-5           No            43.0      93003.0
# 1       More than 20           No            21.0      93033.0
# 2                0-5          Yes            23.0      93035.0
# 3                0-5           No            19.0      93030.0
# 5       More than 20           No            23.0      93033.0
# ...              ...          ...             ...          ...
# 11301          11-20           No            21.0      84041.0
# 11302            0-5           No            19.0      84010.0
# 11306   More than 20           No            23.0      84321.0
# 11314            0-5           No            40.0      84010.0
# 11320           6-10           No            20.0      84606.0
#
#                  EducationLevel                      AreYouStudent  \
# 0          High school graduate                                 No
# 1      Some college - no degree                                 No
# 2      Some college - no degree  Other/ Technical or Trade Program
# 3      Some college - no degree        College/ Grad or Law School
# 5      Some college - no degree                                 No
# ...                         ...                                ...
# 11301      High school graduate                                 No
# 11302      High school graduate                        High School
# 11306        Associate's degree        College/ Grad or Law School
# 11314      High school graduate                                 No
# 11320  Some college - no degree        College/ Grad or Law School
#
#                          AreYouEmployed bac_from_blood
# 0                    Employed Full-time         #NULL!
# 1                    Employed Full-time         #NULL!
# 2      Other __________________________         #NULL!
# 3                    Employed Part-time              0
# 5                    Employed Full-time              0
# ...                                 ...            ...
# 11301                Employed Part-time         #NULL!
# 11302                Employed Full-time         #NULL!
# 11306                Employed Full-time         #NULL!
# 11314                Employed Full-time              0
# 11320                Employed Part-time              0
#
# [6068 rows x 16 columns]

# %%
# Removing #NULL! values from bac_from_blood
data13_df = data13_df[data13_df["bac_from_blood"] != "#NULL!"]
data13_df
# Out:
#        data_session_original State           Time_Stamp race_n  Gender  \
# 3                          3    CA  12/07/2013 02:34:15      8    Male
# 5                          3    CA  12/07/2013 13:28:52      1    Male
# 9                          1    FL  06/28/2013 10:54:21      1    Male
# 15                         4    FL  06/29/2013 23:13:17      1    Male
# 22                         5    FL  06/30/2013 02:30:54      6  Female
# ...                      ...   ...                  ...    ...     ...
# 11287                      4    OK  09/07/2013 23:42:59      1    Male
# 11292                      5    OK  09/08/2013 03:08:10      1    Male
# 11299                      1    UT  02/07/2014 16:37:07      1    Male
# 11314                      4    UT  02/08/2014 23:01:07      5  Female
# 11320                      5    UT  02/09/2014 02:03:32      1  Female
#
#           VehicleType                FromWhere   ToWhere MilesTraveling  \
# 3                 Car      Someone else's home  Own home            0-5
# 5                 Car                    Other     Other   More than 20
# 9      SUV/ Crossover                 Own home     Other           6-10
# 15                Car                 Own home  Own home          11-20
# 22                Car      Someone else's home  Own home            0-5
# ...               ...                      ...       ...            ...
# 11287          Pickup      Someone else's home  Own home           6-10
# 11292          Pickup  Restaurant/eating place  Own home            0-5
# 11299             Car     Store or gas station  Own home            0-5
# 11314             Car  Restaurant/eating place  Own home            0-5
# 11320             Car     Store or gas station     Other           6-10
#
#          AlcoholToday  DriverAgeYears  MyZipCodeIs            EducationLevel  \
# 3                  No            19.0      93030.0  Some college - no degree
# 5                  No            23.0      93033.0  Some college - no degree
# 9                  No            46.0      33125.0          9th - 11th grade
# 15                Yes            25.0      33146.0       Professional degree
# 22                 No            23.0      33137.0        Associate's degree
# ...               ...             ...          ...                       ...
# 11287              No            27.0      73159.0      High school graduate
# 11292  Did not answer            22.0      73728.0       Professional degree
# 11299              No            22.0      84010.0      High school graduate
# 11314              No            40.0      84010.0      High school graduate
# 11320              No            20.0      84606.0  Some college - no degree
#
#                      AreYouStudent                    AreYouEmployed  \
# 3      College/ Grad or Law School                Employed Part-time
# 5                               No                Employed Full-time
# 9                               No                Employed Full-time
# 15                              No                Employed Full-time
# 22     College/ Grad or Law School                Employed Full-time
# ...                            ...                               ...
# 11287                           No                Employed Full-time
# 11292  College/ Grad or Law School  Other __________________________
# 11299                           No                        Unemployed
# 11314                           No                Employed Full-time
# 11320  College/ Grad or Law School                Employed Part-time
#
#       bac_from_blood
# 3                  0
# 5                  0
# 9                  0
# 15                 0
# 22                 0
# ...              ...
# 11287              0
# 11292              0
# 11299              0
# 11314              0
# 11320              0
#
# [3177 rows x 16 columns]

# %%
data13_df["DriverAgeYears"].unique()
# Out:
# array([  19.,   23.,   46.,   25.,   43.,   33.,   26.,   20.,   22.,
#          60.,   69.,   59.,   51.,   45.,   74.,   36.,   64.,   52.,
#          24.,   56.,   30.,   49.,   53.,   18.,   41.,   21.,   27.,
#          44.,   47.,   50.,   31.,   76.,   73.,   48.,   32.,   55.,
#          65.,   63.,   42.,   37.,   28.,   29.,   34.,   70.,   38.,
#          54.,   72.,   62.,   35.,   57.,   58.,   75.,   40.,   39.,
#          79.,   66., 4516.,   71.,   61.,   67.,   82.,   81.,   16.,
#          80.,   78.,   68.,   83.,   77.,   17.,    0.,   99., 7216.])

# %%
# Changing Zipcode and race_n to int64
data13_df = data13_df.astype({"MyZipCodeIs": "int64"
                              ,"race_n": "int64"
                              ,"DriverAgeYears": "int64"
                             })
data13_df.dtypes
# Out:
# data_session_original     int64
# State                    object
# Time_Stamp               object
# race_n                    int64
# Gender                   object
# VehicleType              object
# FromWhere                object
# ToWhere                  object
# MilesTraveling           object
# AlcoholToday             object
# DriverAgeYears            int64
# MyZipCodeIs               int64
# EducationLevel           object
# AreYouStudent            object
# AreYouEmployed           object
# bac_from_blood           object
# dtype: object

# %%
# Getting city name based on zip code in data
search = SearchEngine(simple_zipcode=True)
for index, row in data13_df.iterrows():
    try:
        zipcode = row["MyZipCodeIs"]
        getCityData = search.by_zipcode(zipcode)
        data13_df.loc[index, "CityName"] = getCityData.major_city
    except ValueError:
        print(f"Skipping {index} due to invalid zipcode data")

data13_df.head()
# Out:
#     data_session_original State           Time_Stamp  race_n  Gender  \
# 3                       3    CA  12/07/2013 02:34:15       8    Male
# 5                       3    CA  12/07/2013 13:28:52       1    Male
# 9                       1    FL  06/28/2013 10:54:21       1    Male
# 15                      4    FL  06/29/2013 23:13:17       1    Male
# 22                      5    FL  06/30/2013 02:30:54       6  Female
#
#        VehicleType            FromWhere   ToWhere MilesTraveling AlcoholToday  \
# 3              Car  Someone else's home  Own home            0-5           No
# 5              Car                Other     Other   More than 20           No
# 9   SUV/ Crossover             Own home     Other           6-10           No
# 15             Car             Own home  Own home          11-20          Yes
# 22             Car  Someone else's home  Own home            0-5           No
#
#     DriverAgeYears  MyZipCodeIs            EducationLevel  \
# 3               19        93030  Some college - no degree
# 5               23        93033  Some college - no degree
# 9               46        33125          9th - 11th grade
# 15              25        33146       Professional degree
# 22              23        33137        Associate's degree
#
#                   AreYouStudent      AreYouEmployed bac_from_blood CityName
# 3   College/ Grad or Law School  Employed Part-time              0   Oxnard
# 5                            No  Employed Full-time              0   Oxnard
# 9                            No  Employed Full-time              0    Miami
# 15                           No  Employed Full-time              0    Miami
# 22  College/ Grad or Law School  Employed Full-time              0    Miami

# %%
# Checking Unique values in AreYouEmployed
data13_df["AreYouEmployed"].unique()
# Out:
# array(['Employed Part-time', 'Employed Full-time', 'Unemployed',
#        'Retired', 'On Disability', 'Homemaker',
#        'Other __________________________', 'Did not answer'], dtype=object)

# %%
# Converting AreYouEmployed to binary
data13_df["AreYouEmployed"] = data13_df["AreYouEmployed"].apply(lambda x: 1 if (x == "Employed Part-time") | 
                                                                (x == "Employed Full-time") 
                                                                else 0)
data13_df["AreYouEmployed"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data13_df["AreYouStudent"].unique()
# Out:
# array(['College/ Grad or Law School', 'No',
#        'Other/ Technical or Trade Program', 'High School',
#        'Did not answer'], dtype=object)

# %%
# Converting AreYouStudent to binary
data13_df["AreYouStudent"] = data13_df["AreYouStudent"].apply(lambda x: 1 if (x != "Did not answer") & 
                                                                (x != "No") 
                                                                else 0)
data13_df["AreYouStudent"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# Check unique race values
data13_df["race_n"].unique()
# Out:
# array([8, 1, 6, 9, 7, 3, 2, 5, 4], dtype=int64)

# %%
# Replacing numeric race values with string
race_dict = {1: "White"
             ,2: "Black/African American"
             ,3: "Asian"
             ,4: "Native American/Alaskan"
             ,5: "Native Hawaiian/Other Pacific Islander"
             ,6: "Unknown"
             ,7: "Other"
             ,8: "More than one"
             ,9: "no response"
            }
data13_df["race_n"] = data13_df["race_n"].map(lambda x: race_dict.get(x) if x in race_dict else x)
data13_df
# Out:
#        data_session_original State           Time_Stamp  \
# 3                          3    CA  12/07/2013 02:34:15
# 5                          3    CA  12/07/2013 13:28:52
# 9                          1    FL  06/28/2013 10:54:21
# 15                         4    FL  06/29/2013 23:13:17
# 22                         5    FL  06/30/2013 02:30:54
# ...                      ...   ...                  ...
# 11287                      4    OK  09/07/2013 23:42:59
# 11292                      5    OK  09/08/2013 03:08:10
# 11299                      1    UT  02/07/2014 16:37:07
# 11314                      4    UT  02/08/2014 23:01:07
# 11320                      5    UT  02/09/2014 02:03:32
#
#                                        race_n  Gender     VehicleType  \
# 3                               More than one    Male             Car
# 5                                       White    Male             Car
# 9                                       White    Male  SUV/ Crossover
# 15                                      White    Male             Car
# 22                                    Unknown  Female             Car
# ...                                       ...     ...             ...
# 11287                                   White    Male          Pickup
# 11292                                   White    Male          Pickup
# 11299                                   White    Male             Car
# 11314  Native Hawaiian/Other Pacific Islander  Female             Car
# 11320                                   White  Female             Car
#
#                      FromWhere   ToWhere MilesTraveling    AlcoholToday  \
# 3          Someone else's home  Own home            0-5              No
# 5                        Other     Other   More than 20              No
# 9                     Own home     Other           6-10              No
# 15                    Own home  Own home          11-20             Yes
# 22         Someone else's home  Own home            0-5              No
# ...                        ...       ...            ...             ...
# 11287      Someone else's home  Own home           6-10              No
# 11292  Restaurant/eating place  Own home            0-5  Did not answer
# 11299     Store or gas station  Own home            0-5              No
# 11314  Restaurant/eating place  Own home            0-5              No
# 11320     Store or gas station     Other           6-10              No
#
#        DriverAgeYears  MyZipCodeIs            EducationLevel  AreYouStudent  \
# 3                  19        93030  Some college - no degree              1
# 5                  23        93033  Some college - no degree              0
# 9                  46        33125          9th - 11th grade              0
# 15                 25        33146       Professional degree              0
# 22                 23        33137        Associate's degree              1
# ...               ...          ...                       ...            ...
# 11287              27        73159      High school graduate              0
# 11292              22        73728       Professional degree              1
# 11299              22        84010      High school graduate              0
# 11314              40        84010      High school graduate              0
# 11320              20        84606  Some college - no degree              1
#
#        AreYouEmployed bac_from_blood       CityName
# 3                   1              0         Oxnard
# 5                   1              0         Oxnard
# 9                   1              0          Miami
# 15                  1              0          Miami
# 22                  1              0          Miami
# ...               ...            ...            ...
# 11287               1              0  Oklahoma City
# 11292               0              0       Cherokee
# 11299               0              0      Bountiful
# 11314               1              0      Bountiful
# 11320               1              0          Provo
#
# [3177 rows x 17 columns]

# %% [markdown]
# #### Team Member: Jagrati Joshi
#     End of Task of sourcing data from csv files, cleaning up data and saving in 2 dataframes - data07_df and data13_df

# %%
# Exporting Final cleaned data to csv
# Naming the index of the dataframe for export to csv
data13_df.index.names = ["nrs_id"]

# Exporting the data to CSV file
data13_df.to_csv(output13_data_file)
