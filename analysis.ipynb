# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data07_path = "Resource/nrs_2007_final.csv"
data13_path = "Resource/nrs_2013_combined.csv"

data07_df = pd.read_csv(data07_path)
col_list = data07_df.columns.values.tolist()
col_list
# Out:
# ['DIN',
#  'session',
#  'SESSION1',
#  'timeday',
#  'STATE',
#  'NRS_AREA',
#  'DATE',
#  'psu',
#  'eligible',
#  'nrsagree_r',
#  'weight',
#  'NRS_HEARB4',
#  'NRS_DAGE',
#  'NRS_DHISP',
#  'NRS_FRONTPAS',
#  'NRS_DRACE',
#  'NRS_PAS1READ',
#  'NRS_LANGUAGE',
#  'NRS_AVMILE',
#  'NRS_PERDR',
#  'NRS_LIVEMI',
#  'NRS_FROM',
#  'NRS_HEADED',
#  'NRS_BETMI',
#  'NRS_INTOX1',
#  'NRS_PAS2READ',
#  'NRS_EVDRK',
#  'NRS_DRKRTYPE',
#  'NRS_DRINKWEEK',
#  'NRS_TODRK',
#  'NRS_todrknew',
#  'NRS_HRSDRK',
#  'NRS_MINDRK',
#  'NRS_TYPDRK',
#  'NRS_DRKDRV',
#  'NRS_TMSDRV',
#  'NRS_DESDRV',
#  'NRS_AGE',
#  'NRS_ZIPCODE',
#  'NRS_SCHOOL',
#  'NRS_EMPLOY',
#  'NRS_LATINO',
#  'NRS_RACE',
#  'NRS_TOTMI',
#  'NRS_NUMDRVS',
#  'NRS_CRASH',
#  'AUD_SCREENER',
#  'AUD_SCREENERN',
#  'NRS_VTYPE',
#  'NRS_DSEX',
#  'NRS_DBELT',
#  'NRS_PBELT',
#  'NRS_NUMPASS',
#  'NRS_PASS15',
#  'DQP1Q1',
#  'DQP1Q2',
#  'DQP1Q3',
#  'DQP1Q4',
#  'DQP1Q5',
#  'DQP1Q6',
#  'DQP1Q7',
#  'DQP1Q8',
#  'DQP1Q9',
#  'DQP1Q10',
#  'DQP1Q11',
#  'DQP1Q12',
#  'DQP1Q13',
#  'DQP1Q14',
#  'DQP1Q15',
#  'DQP1Q16',
#  'DQP1Q17',
#  'DQP1Q18',
#  'DQP1Q19',
#  'DQP1Q20',
#  'DQP1Q21',
#  'DQP1Q22',
#  'DQP1Q23',
#  'DQP2Q24',
#  'DQP2Q25',
#  'DQP2Q26',
#  'DQP2Q27',
#  'DQP2Q28',
#  'DQP2Q29A',
#  'DQP2Q29B',
#  'DQP2Q29C',
#  'DQP2Q29D',
#  'DQP2Q29E',
#  'DQP2Q29F',
#  'DQP2Q29G',
#  'DQP2Q29H',
#  'DQP2Q29I',
#  'DQP2Q29I_E',
#  'DQP2Q30',
#  'DQP2Q31',
#  'DQP2Q32',
#  'DQP3_MARIJ',
#  'DQP3_COCAI',
#  'DQP3_PAIN_',
#  'DQP3Q1A',
#  'DQP3Q1B',
#  'DQP3Q1C',
#  'DQP3Q2A',
#  'DQP3Q2B',
#  'DQP3Q2C',
#  'DQP3Q3A',
#  'DQP3Q3B',
#  'DQP3Q3C',
#  'DQP3Q4A',
#  'DQP3Q4B',
#  'DQP3Q4C',
#  'DQP3Q5A',
#  'DQP3Q5B',
#  'DQP3Q5C',
#  'DQP3Q6A',
#  'DQP3Q6B',
#  'DQP3Q6C',
#  'DQP3Q7A',
#  'DQP3Q7B',
#  'DQP3Q7C',
#  'DQP3Q8A',
#  'DQP3Q8B',
#  'DQP3Q8C',
#  'DQP3Q9A',
#  'DQP3Q9B',
#  'DQP3Q9C',
#  'DQP3Q10A',
#  'DQP3Q10B',
#  'DQP3Q10C',
#  'DQP3Q11A',
#  'DQP3Q11B',
#  'DQP3Q11C',
#  'DQP3Q12A',
#  'DQP3Q12B',
#  'DQP3Q12C',
#  'DQP4Q1',
#  'DQP4Q2',
#  'DQP4Q3',
#  'DQP4Q4',
#  'DQP4Q5',
#  'DQP4Q6',
#  'DQP4Q7',
#  'DQP4Q8',
#  'DQP4Q9',
#  'DQP4Q10',
#  'DQP4Q11',
#  'DQP4Q12',
#  'DQP4Q13',
#  'DQP4Q14',
#  'DQP4Q15',
#  'DQP4Q16',
#  'DQP4Q17',
#  'DQP4Q18',
#  'DQP4Q19',
#  'BLD_DRUG',
#  'BLD_ETHANOL',
#  'OF_DRUG',
#  'OF_ETHANOL',
#  'OF_BLD_drugpos',
#  'OF_BLD_Illegal',
#  'OF_BLD_Marijuana',
#  'OF_BLD_Sedatives',
#  'OF_BLD_CLASS',
#  'OF_BLD_numCLASS',
#  'OF_BLD_category',
#  'OF_BLD_Othercat',
#  'BLD_drugpos',
#  'BLD_illegal',
#  'BLD_prescription',
#  'BLD_over_the_counter',
#  'BLD_category',
#  'OF_category',
#  'OF_class',
#  'OF_drugpos',
#  'OF_illegal',
#  'OF_prescription',
#  'OF_over_the_counter',
#  'OF_NARCOTIC_ANALGESICS',
#  'OF_OTHER',
#  'BLD_Amphetamines',
#  'BLD_COCAINE',
#  'BLD_STIMULANTS',
#  'BLD_barbiturates',
#  'BLD_benzodiazepines',
#  'BLD_cannabinoids',
#  'BLD_carisoprodol',
#  'BLD_cough_suppr',
#  'BLD_methadone',
#  'BLD_opiates',
#  'BLD_pain_killers',
#  'BLD_sleep_aids',
#  'BLD_streets',
#  'BLD_tryc_antidepres',
#  'BLD_antidepressants',
#  'BLD_NARCOTIC_ANALGESICS',
#  'BLD_SEDATIVES',
#  'BLD_other_cat',
#  'OF_COCAINE',
#  'OF_antidepressants',
#  'OF_barbiturates',
#  'OF_benzodiazepines',
#  'OF_pain_killers',
#  'OF_streets',
#  'OF_tryc_antidepres',
#  'OF_cough_suppr',
#  'OF_methadone',
#  'OF_opiates',
#  'OF_STIMULANTS',
#  'OF_Amphetamines',
#  'of_carisoprodol',
#  'of_sleep_aids',
#  'of_SEDATIVES',
#  'of_cannabinoids',
#  'of_MARIJUANA',
#  'BLD_ALP_DOS',
#  'BLD_AMITRI_DOS',
#  'BLD_AMP_DOS',
#  'BLD_BARB_DOS',
#  'BLD_BUTAL_DOS',
#  'BLD_BZE_DOS',
#  'BLD_CARISO_DOS',
#  'BLD_CE_DOS',
#  'BLD_CHLOR_DOS',
#  'BLD_CLONA_DOS',
#  'BLD_CODEINE_DOS',
#  'BLD_DEXTROMETHORPHAN_DOS',
#  'BLD_DIAZEP_DOS',
#  'BLD_FLUO_DOS',
#  'BLD_HYC_DOS',
#  'BLD_HYM_DOS',
#  'BLD_KETAMINE_DOS',
#  'BLD_LORAZ_DOS',
#  'BLD_MDA_DOS',
#  'BLD_MDMA_DOS',
#  'BLD_MEPERIDINE_DOS',
#  'BLD_MEPRO_DOS',
#  'BLD_METHADONE_DOS',
#  'BLD_METHYL_DOS',
#  'BLD_METH_DOS',
#  'BLD_MORPHINE_DOS',
#  'BLD_NC_DOS',
#  'BLD_NORDIAZ_DOS',
#  'BLD_NORKETAMINE_DOS',
#  'BLD_NORTRI_DOS',
#  'BLD_OXAZE_DOS',
#  'BLD_OXYC_DOS',
#  'BLD_PCP_DOS',
#  'BLD_PHENO_DOS',
#  'BLD_PROPOXYPHENE_DOS',
#  'BLD_SIX_AC_DOS',
#  'BLD_SIX_AM_DOS',
#  'BLD_temaze_DOS',
#  'BLD_THC_DOS',
#  'BLD_TRAMADOL_DOS',
#  'BLD_ZOLPI_DOS',
#  'BLD_Phentermine_DOS',
#  'BLD_SERTRA_DOS',
#  'BLD_COC_DOS',
#  'OF_ALP_DOS',
#  'OF_AMITRI_DOS',
#  'OF_AMP_DOS',
#  'OF_BARB_DOS',
#  'OF_BUTAL_DOS',
#  'OF_BZE_DOS',
#  'OF_CARISO_DOS',
#  'OF_CE_DOS',
#  'OF_CHLOR_DOS',
#  'OF_CLONA_DOS',
#  'OF_COC_DOS',
#  'OF_CODEINE_DOS',
#  'OF_DEXTROMETHORPHAN_DOS',
#  'OF_DIAZEP_DOS',
#  'OF_FLUO_DOS',
#  'OF_HYC_DOS',
#  'OF_HYM_DOS',
#  'OF_KETAMINE_DOS',
#  'OF_LORAZ_DOS',
#  'OF_MDA_DOS',
#  'OF_MDMA_DOS',
#  'OF_MEPERIDINE_DOS',
#  'OF_MEPRO_DOS',
#  'OF_METHADONE_DOS',
#  'OF_METHYL_DOS',
#  'OF_METH_DOS',
#  'OF_MORPHINE_DOS',
#  'OF_NC_DOS',
#  'OF_NORDIAZ_DOS',
#  'OF_NORKETAMINE_DOS',
#  'OF_NORTRI_DOS',
#  'OF_OXAZE_DOS',
#  'OF_OXYC_DOS',
#  'OF_PCP_DOS',
#  'OF_PHENO_DOS',
#  'OF_PROPOXYPHENE_DOS',
#  'OF_Phentermine_DOS',
#  'OF_SERTRA_DOS',
#  'OF_SIX_AM_DOS',
#  'OF_SIX_AC_DOS',
#  'OF_temaze_DOS',
#  'OF_THC_DOS',
#  'OF_TRAMADOL_DOS',
#  'OF_ZOLPI_DOS',
#  'resulbac2',
#  'resulbac2_imp',
#  'bac08',
#  'AUD_OFFERED',
#  'AUD_CURRENT',
#  'AUD_COMPLETE',
#  'AUD_DEPEND',
#  'AUD_ABUSE',
#  'AUD_HEAVYD',
#  'AUD_BINGE',
#  'AUD_NORMATIVE',
#  'AUD_CAT']
