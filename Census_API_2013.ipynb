# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json 
import csv
import os

#output file
output_data_file = "Census_output/Census_data_total_2013.csv"

# Files to load
pop = os.path.join('Population_Resources', 'state-population.csv')
age =  os.path.join('Population_Resources', 'raw_data_age_2013.csv')
race = os.path.join('Population_Resources', 'raw_data_race_2013.csv')
gender = os.path.join('Population_Resources','raw_data_gender_2013.csv')
employment = os.path.join('Population_Resources', 'raw_data_employment_2013.csv')

pop_df = pd.read_csv(pop,skiprows=3, names=['State_Census_2013',"ages_Census_2013", "year_Census_2013",'Population_Census_2013'])
age_df = pd.read_csv(age, skiprows=3,names=['State_Census_2013',"Children 0-18_Census_2013", "Adults 19-25_Census_2013",
                                            "Adults 26-34_Census_2013", "Adults 35-54_Census_2013",'Adults 55-64_Census_2013','65+_Census_2013','Total','8'])
race_df = pd.read_csv(race, skiprows=3,names=['State_Census_2013',"White_Census_2013", "Hispanic_Census_2013","Black_Census_2013",'American Indian/Alaska Native_Census_2013',
                                      'Asian+_Census_2013','Native Hawaiian/Other Pacific Islander_Census_2013',
                                      'Two Or More Races_Census_2013', 'Total', 'Delete'])
gender_df = pd.read_csv(gender, skiprows=3, names=['State_Census_2013','Male_Census_2013',"Female_Census_2013", "Total",'Delete'])
employment_df = pd.read_csv(employment, skiprows=3, names=['State_Census_2013','Delete1',"Delete2", "Unemployed_Census_2013",'Employed','Delete3'])

# %%
pop_total = pop_df[pop_df ["ages_Census_2013"] == 'total'] 
pop_year_2013 = pop_total[pop_total['year_Census_2013'] == 2013]
pop_year_2013 = pop_year_2013.drop(columns=['ages_Census_2013', 'year_Census_2013'])
pop_year_2013.columns = ['State_Census_2013', 'Population_Census_2013']
pop_year_2013 = pop_year_2013.replace(['USA'],'United States')
pop_year_2013 = pop_year_2013.replace(['AK'], 'Alaska')
pop_year_2013 = pop_year_2013.replace(['AL'], 'Alabama')
pop_year_2013 = pop_year_2013.replace(['AR'], 'Arkansas')
pop_year_2013 = pop_year_2013.replace(['AS'], 'American Samoa')
pop_year_2013 = pop_year_2013.replace(['AZ'], 'Arizona')
pop_year_2013 = pop_year_2013.replace(['CA'], 'California')
pop_year_2013 = pop_year_2013.replace(['CO'], 'Colorado')
pop_year_2013 = pop_year_2013.replace(['CT'], 'Connecticut')
pop_year_2013 = pop_year_2013.replace(['DC'], 'District of Columbia')
pop_year_2013 = pop_year_2013.replace(['DE'], 'Delaware')
pop_year_2013 = pop_year_2013.replace(['FL'], 'Florida')
pop_year_2013 = pop_year_2013.replace(['GA'], 'Georgia')
pop_year_2013 = pop_year_2013.replace(['GU'], 'Guam')
pop_year_2013 = pop_year_2013.replace(['HI'], 'Hawaii')
pop_year_2013 = pop_year_2013.replace(['IA'], 'Iowa')
pop_year_2013 = pop_year_2013.replace(['ID'], 'Idaho')
pop_year_2013 = pop_year_2013.replace(['IL'], 'Illinois')
pop_year_2013 = pop_year_2013.replace(['IN'], 'Indiana')
pop_year_2013 = pop_year_2013.replace(['KS'], 'Kansas')
pop_year_2013 = pop_year_2013.replace(['KY'], 'Kentucky')
pop_year_2013 = pop_year_2013.replace(['LA'], 'Louisiana')
pop_year_2013 = pop_year_2013.replace(['MA'], 'Massachusetts')
pop_year_2013 = pop_year_2013.replace(['MD'], 'Maryland')
pop_year_2013 = pop_year_2013.replace(['ME'], 'Maine')
pop_year_2013 = pop_year_2013.replace(['MI'], 'Michigan')
pop_year_2013 = pop_year_2013.replace(['MN'], 'Minnesota')
pop_year_2013 = pop_year_2013.replace(['MO'], 'Missouri')
pop_year_2013 = pop_year_2013.replace(['MP'], 'Northern Mariana Islands')
pop_year_2013 = pop_year_2013.replace(['MS'], 'Mississippi')
pop_year_2013 = pop_year_2013.replace(['MT'], 'Montana')
pop_year_2013 = pop_year_2013.replace(['NA'], 'National')
pop_year_2013 = pop_year_2013.replace(['NC'], 'North Carolina')
pop_year_2013 = pop_year_2013.replace(['ND'], 'North Dakota')
pop_year_2013 = pop_year_2013.replace(['NE'], 'Nebraska')
pop_year_2013 = pop_year_2013.replace(['NH'], 'New Hampshire')
pop_year_2013 = pop_year_2013.replace(['NJ'], 'New Jersey')
pop_year_2013 = pop_year_2013.replace(['NM'], 'New Mexico')
pop_year_2013 = pop_year_2013.replace(['NV'], 'Nevada')
pop_year_2013 = pop_year_2013.replace(['NY'], 'New York')
pop_year_2013 = pop_year_2013.replace(['OH'], 'Ohio')
pop_year_2013 = pop_year_2013.replace(['OK'], 'Oklahoma')
pop_year_2013 = pop_year_2013.replace(['OR'], 'Oregon')
pop_year_2013 = pop_year_2013.replace(['PA'], 'Pennsylvania')
pop_year_2013 = pop_year_2013.replace(['PR'], 'Puerto Rico')
pop_year_2013 = pop_year_2013.replace(['RI'], 'Rhode Island')
pop_year_2013 = pop_year_2013.replace(['SC'], 'South Carolina')
pop_year_2013 = pop_year_2013.replace(['SD'], 'South Dakota')
pop_year_2013 = pop_year_2013.replace(['TN'], 'Tennessee')
pop_year_2013 = pop_year_2013.replace(['TX'], 'Texas')
pop_year_2013 = pop_year_2013.replace(['UT'], 'Utah')
op_year_2007 = pop_year_2013.replace(['VA'], 'Virginia')
pop_year_2013 = pop_year_2013.replace(['VI'], 'Virgin Islands')
pop_year_2013 = pop_year_2013.replace(['VT'], 'Vermont')
pop_year_2013 = pop_year_2013.replace(['WA'], 'Washington')
pop_year_2013 = pop_year_2013.replace(['WI'], 'Wisconsin',)
pop_year_2013 = pop_year_2013.replace(['WV'], 'West Virginia')
pop_year_2013 = pop_year_2013.replace(['WY'], 'Wyoming')
pop_year_2013
# Out:
#          State_Census_2013  Population_Census_2013
# 37           United States             316128839.0
# 54                 Alabama               4833722.0
# 132                 Alaska                735132.0
# 148                Arizona               6626624.0
# 230               Arkansas               2959373.0
# 244             California              38332521.0
# 326               Colorado               5268367.0
# 340            Connecticut               3596080.0
# 420               Delaware                925749.0
# 436   District of Columbia                646449.0
# 518                Florida              19552860.0
# 531                Georgia               9992167.0
# 614                 Hawaii               1404054.0
# 627                  Idaho               1612136.0
# 710               Illinois              12882135.0
# 723                Indiana               6570902.0
# 806                   Iowa               3090416.0
# ...

# %%
race_df = race_df.drop(columns=['Delete'])
race_df = race_df.drop(columns=['Total'])
race_df.head()
# Out:
#   State_Census_2013  White_Census_2013  Hispanic_Census_2013  \
# 0     United States        192379500.0            37122600.0
# 1           Alabama          3136100.0             1232900.0
# 2            Alaska           441000.0               23600.0
# 3           Arizona          3675000.0              249900.0
# 4          Arkansas          2116100.0              442400.0
#
#    Black_Census_2013  American Indian/Alaska Native_Census_2013  \
# 0         52764900.0                                  2008700.0
# 1           184500.0                                    17900.0
# 2            44100.0                                    97400.0
# 3          1951200.0                                   250800.0
# 4           197600.0                                    16200.0
#
#    Asian+_Census_2013  Native Hawaiian/Other Pacific Islander_Census_2013  \
# 0          15505700.0                                           448800.0
# ...

# %%
gender_df = gender_df.drop(columns=['Delete','Total'])
gender_df = gender_df.dropna()
gender_df.head()
# Out:
#   State_Census_2013  Male_Census_2013  Female_Census_2013
# 0     United States              0.49                0.51
# 1           Alabama              0.48                0.52
# 2            Alaska              0.52                0.48
# 3           Arizona              0.49                0.51
# 4          Arkansas              0.49                0.51

# %%
employment_df = employment_df.drop(columns=['Delete1','Delete2', 'Delete3'])
employment_df = employment_df.dropna()
employment_df.head()
# Out:
#   State_Census_2013  Unemployed_Census_2013     Employed
# 0     United States              31254000.0  264151600.0
# 1           Alabama                678000.0    4004400.0
# 2            Alaska                 66500.0     638800.0
# 3           Arizona                724000.0    5460900.0
# 4          Arkansas                372900.0    2430900.0

# %%
age_df = age_df.drop(columns=['8'])
age_df = age_df.drop(columns=['Total'])
age_df = age_df.dropna()
age_df.head()
# Out:
#   State_Census_2013  Children 0-18_Census_2013  Adults 19-25_Census_2013  \
# 0     United States                 76054600.0                28894900.0
# 1           Alabama                  1165900.0                  441800.0
# 2            Alaska                   191600.0                   75300.0
# 3           Arizona                  1668100.0                  615800.0
# 4          Arkansas                   731400.0                  255500.0
#
#    Adults 26-34_Census_2013  Adults 35-54_Census_2013  \
# 0                37013500.0                83185000.0
# 1                  533800.0                 1246600.0
# 2                   96000.0                  186900.0
# 3                  771600.0                 1631200.0
# 4                  337700.0                  742800.0
#
#    Adults 55-64_Census_2013  65+_Census_2013
# 0                39003500.0       43354000.0
# 1                  616200.0         701400.0
# 2                   88900.0          66300.0
# ...

# %%
Census_data_1 = pd.merge(race_df,gender_df, on=["State_Census_2013"])
Census_data_1.head()
# Out:
#   State_Census_2013  White_Census_2013  Hispanic_Census_2013  \
# 0     United States        192379500.0            37122600.0
# 1           Alabama          3136100.0             1232900.0
# 2            Alaska           441000.0               23600.0
# 3           Arizona          3675000.0              249900.0
# 4          Arkansas          2116100.0              442400.0
#
#    Black_Census_2013  American Indian/Alaska Native_Census_2013  \
# 0         52764900.0                                  2008700.0
# 1           184500.0                                    17900.0
# 2            44100.0                                    97400.0
# 3          1951200.0                                   250800.0
# 4           197600.0                                    16200.0
#
#    Asian+_Census_2013  Native Hawaiian/Other Pacific Islander_Census_2013  \
# 0          15505700.0                                           448800.0
# ...

# %%
Census_data_2 = pd.merge(Census_data_1,employment_df, on=["State_Census_2013"])
Census_data_2.head()
# Out:
#   State_Census_2013  White_Census_2013  Hispanic_Census_2013  \
# 0     United States        192379500.0            37122600.0
# 1           Alabama          3136100.0             1232900.0
# 2            Alaska           441000.0               23600.0
# 3           Arizona          3675000.0              249900.0
# 4          Arkansas          2116100.0              442400.0
#
#    Black_Census_2013  American Indian/Alaska Native_Census_2013  \
# 0         52764900.0                                  2008700.0
# 1           184500.0                                    17900.0
# 2            44100.0                                    97400.0
# 3          1951200.0                                   250800.0
# 4           197600.0                                    16200.0
#
#    Asian+_Census_2013  Native Hawaiian/Other Pacific Islander_Census_2013  \
# 0          15505700.0                                           448800.0
# ...

# %%
Census_data_3 = pd.merge(Census_data_2,age_df, on=["State_Census_2013"])
Census_data_3.head()
# Out:
#   State_Census_2013  White_Census_2013  Hispanic_Census_2013  \
# 0     United States        192379500.0            37122600.0
# 1           Alabama          3136100.0             1232900.0
# 2            Alaska           441000.0               23600.0
# 3           Arizona          3675000.0              249900.0
# 4          Arkansas          2116100.0              442400.0
#
#    Black_Census_2013  American Indian/Alaska Native_Census_2013  \
# 0         52764900.0                                  2008700.0
# 1           184500.0                                    17900.0
# 2            44100.0                                    97400.0
# 3          1951200.0                                   250800.0
# 4           197600.0                                    16200.0
#
#    Asian+_Census_2013  Native Hawaiian/Other Pacific Islander_Census_2013  \
# 0          15505700.0                                           448800.0
# ...

# %%
Census_data_total = pd.merge(Census_data_3,pop_year_2013, on=["State_Census_2013"])
Census_data_total
# Out:
#        State_Census_2013  White_Census_2013  Hispanic_Census_2013  \
# 0          United States        192379500.0            37122600.0
# 1                Alabama          3136100.0             1232900.0
# 2                 Alaska           441000.0               23600.0
# 3                Arizona          3675000.0              249900.0
# 4               Arkansas          2116100.0              442400.0
# 5             California         14572300.0             2061400.0
# 6               Colorado          3558300.0              183600.0
# 7            Connecticut          2419300.0              333500.0
# 8               Delaware           577900.0              184300.0
# 9   District of Columbia           214500.0              296700.0
# 10               Florida         10748400.0             2897800.0
# 11               Georgia          5316200.0             2948800.0
# 12                Hawaii           289000.0               20400.0
# ...

# %%
Census_data_total.to_csv(output_data_file)
